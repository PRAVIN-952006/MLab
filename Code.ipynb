# %%
import pandas as pd
import numpy as np
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import kagglehub

# %% [markdown]
# ## Importing Dataset

# %%
path = kagglehub.dataset_download("phileinsophos/predict-loan-amount-data")
print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/phileinsophos/predict-loan-amount-data?dataset_version_number=1...
# 100%|██████████| 2.44M/2.44M [00:00<00:00, 123MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/phileinsophos/predict-loan-amount-data/versions/1

# %%
train = pd.read_csv(f"{path}/train.csv")
test = pd.read_csv(f"{path}/test.csv")

# %%
train.shape, test.shape
# Out:
# ((30000, 24), (20000, 23))

# %%
train.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)',
#        'Income Stability', 'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price', 'Loan Sanction Amount (USD)'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)',
#        'Income Stability', 'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price'],
#       dtype='object')

# %% [markdown]
# So Loan Sanction Amount is the target variable

# %% [markdown]
# ## Preprocessing

# %%
train.drop(columns=['Customer ID','Name','Property ID'], inplace=True)

# %% [markdown]
# ### Handling missing values

# %%
train.isnull().sum()
# Out:
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %% [markdown]
# Gender

# %% [markdown]
# Since Gender is a categorical variable mode is used to fill the missing values

# %%
train['Gender'] = train['Gender'].fillna(train['Gender'].mode()[0])

# %% [markdown]
# Income

# %% [markdown]
# Median is choosen coz using median keeps the overall scale and spread closer to the original distribution.

# %%
sns.histplot(train['Income (USD)'], kde=True)
plt.xlim(0, 15000)
plt.show()

# %% [markdown]
# In skewed distributions, the median is more representative of what most users are like.

# %%
train['Income (USD)']=train['Income (USD)'].fillna(train['Income (USD)'].median())

# %% [markdown]
# Income Stability

# %% [markdown]
# Since Income Stability is a categorical variable mode is used to fill the missing values

# %%
train['Income Stability']=train['Income Stability'].fillna(train['Income Stability'].mode()[0])

# %% [markdown]
# Type of Employment

# %% [markdown]
# Due to high missing value(7270) this column is dropped

# %%
train.drop(columns=['Type of Employment'], inplace=True)

# %% [markdown]
# Current Loan Expenses (USD)

# %%
sns.histplot(train['Current Loan Expenses (USD)'], kde=True)
plt.xlim(0,1200)
plt.show()

# %% [markdown]
# In skewed distributions, the median is more representative of what most users are like.

# %%
train['Current Loan Expenses (USD)']=train['Current Loan Expenses (USD)'].fillna(train['Current Loan Expenses (USD)'].median())

# %% [markdown]
# Dependents

# %%
train['Dependents']=train['Dependents'].fillna(0)

# %% [markdown]
# Credit Score

# %%
sns.histplot(train['Credit Score'], kde=True)
plt.xlim(train['Credit Score'].min(), train['Credit Score'].max())
plt.show()

# %% [markdown]
# Since the credit scores are fairly symmetrical and centered and there aren’t major outliers.Mean can be used

# %%
train['Credit Score']=train['Credit Score'].fillna(train['Credit Score'].mean())

# %% [markdown]
# Has Active Credit Card

# %% [markdown]
# Since it is a categorical feature mode is used.

# %%
train['Has Active Credit Card']=train['Has Active Credit Card'].fillna(train['Has Active Credit Card'].mode()[0])

# %% [markdown]
# Property Age

# %%
train.drop(columns=['Property Age'], inplace=True)

# %% [markdown]
# Property Location

# %% [markdown]
# Since it is a categorical feature mode is used

# %%
train['Property Location']=train['Property Location'].fillna(train['Property Location'].mode()[0])

# %% [markdown]
# Loan Sanction Amount

# %% [markdown]
# We need the target feature values to make assumptions.

# %%
train.dropna(subset=['Loan Sanction Amount (USD)'], inplace=True)

# %%
train.isnull().sum()
# Out:
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64

# %%
train.shape
# Out:
# (29660, 19)

# %% [markdown]
# ### Outlier Treatment

# %%
train_before = train.copy()

# %%
def remove_outliers_iqr(df, columns):
    mask = pd.Series([True] * len(df), index=df.index)
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        mask &= df[col].between(lower_bound, upper_bound)
    return df[mask]

# %%
num_cols_to_check = [
    'Income (USD)',
    'Current Loan Expenses (USD)',
    'Credit Score',
    'Dependents',
    'Loan Amount Request (USD)',
    'Property Price',
    'Loan Sanction Amount (USD)'
]
print("Before:", train.shape)
train = remove_outliers_iqr(train, num_cols_to_check)
print("After:", train.shape)
# Out:
# Before: (29660, 19)
# After: (26585, 19)

# %%
plt.figure(figsize=(16, 12))
gs = gridspec.GridSpec(len(num_cols_to_check), 2)

for i, col in enumerate(num_cols_to_check):
    # Before
    ax1 = plt.subplot(gs[i, 0])
    sns.boxplot(x=train_before[col], ax=ax1, color="skyblue")
    ax1.set_title(f"Before - {col}")

    # After
    ax2 = plt.subplot(gs[i, 1])
    sns.boxplot(x=train[col], ax=ax2, color="lightgreen")
    ax2.set_title(f"After - {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Categorical Analysis

# %% [markdown]
# #### univariate Analysis

# %%
categorical_cols = [
    'Gender',
    'Income Stability',
    'Profession',
    'Location',
    'Expense Type 1',
    'Expense Type 2',
    'Has Active Credit Card',
    'Property Type',
    'Property Location',
    'Co-Applicant'
]
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, data=train, order=train[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Bivariate Analysis

# %%
anova_results = []
from scipy.stats import f_oneway
for col in categorical_cols:
    # Perform ANOVA to test if means differ significantly
    groups = [train['Loan Sanction Amount (USD)'][train[col] == level] for level in train[col].dropna().unique()]
    if len(groups) > 1:
        f_stat, p_val = f_oneway(*groups)
        anova_results.append((col, p_val))
anova_df = pd.DataFrame(anova_results, columns=['Categorical Feature', 'p-value'])
anova_df['Significant (p < 0.05)'] = anova_df['p-value'] < 0.05
print("\nANOVA Results:")
print(anova_df.sort_values(by='p-value'))
# Out:
# ANOVA Results:
#       Categorical Feature       p-value  Significant (p < 0.05)
# 9            Co-Applicant  0.000000e+00                    True
# 2              Profession  2.255225e-47                    True
# 3                Location  7.629250e-32                    True
# 1        Income Stability  5.085348e-20                    True
# 4          Expense Type 1  8.267140e-05                    True
# 5          Expense Type 2  7.128996e-02                   False
# 6  Has Active Credit Card  8.565205e-02                   False
# 8       Property Location  1.600163e-01                   False
# 0                  Gender  7.343009e-01                   False
# 7           Property Type  8.729814e-01                   False

# %%
train.drop(columns=['Expense Type 2','Has Active Credit Card','Property Location','Gender','Property Type'], inplace=True)

# %% [markdown]
# ### Numerical Analysis

# %%
matrix = train[['Income (USD)','Loan Amount Request (USD)','Current Loan Expenses (USD)','Dependents','Credit Score','No. of Defaults','Property Price','Loan Sanction Amount (USD)']].corr()
sns.heatmap(matrix, vmax=.8, square=True, cmap="BuPu",annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Dropping Dependents and No. of Defaults due to weak correlation

# %%
train.drop(columns=['Dependents','No. of Defaults', 'Income (USD)'], inplace=True)

# %% [markdown]
# ### Encoding Categorical Columns

# %%
categorical_cols = [
    'Income Stability',
    'Profession',
    'Location',
    'Expense Type 1',
    'Co-Applicant'
]
train[categorical_cols].nunique()
# Out:
# Income Stability    2
# Profession          7
# Location            3
# Expense Type 1      2
# Co-Applicant        3
# dtype: int64

# %%
train_encoded = pd.get_dummies(train, columns=categorical_cols, drop_first=True)

# %%
train_encoded.columns
# Out:
# Index(['Age', 'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Credit Score', 'Property Price', 'Loan Sanction Amount (USD)',
#        'Income Stability_Low', 'Profession_Commercial associate',
#        'Profession_Pensioner', 'Profession_State servant',
#        'Profession_Student', 'Profession_Unemployed', 'Profession_Working',
#        'Location_Semi-Urban', 'Location_Urban', 'Expense Type 1_Y',
#        'Co-Applicant_0', 'Co-Applicant_1'],
#       dtype='object')

# %% [markdown]
# ### Standardize

# %%
from sklearn.preprocessing import StandardScaler
target = 'Loan Sanction Amount (USD)'
numerical_features = ['Age', 'Loan Amount Request (USD)',
                      'Current Loan Expenses (USD)', 'Credit Score', 'Property Price']

# Standardize numeric features
scaler = StandardScaler()
train_encoded[numerical_features] = scaler.fit_transform(train_encoded[numerical_features])

# %% [markdown]
# ## Preprocess Test

# %%
test.drop(columns=['Customer ID','Name','Property ID','Type of Employment','Property Age','Property Location','Gender','Property Type','Dependents','No. of Defaults'], inplace=True)

# %%
test_encoded = pd.get_dummies(test, columns=categorical_cols, drop_first=True)

# %%
test_encoded.columns
test_encoded
# Out:
#        Age  Income (USD)  Loan Amount Request (USD)  \
# 0       47       3472.69                  137088.98
# 1       57       1184.84                  104771.59
# 2       52       1266.27                  176684.91
# 3       65       1369.72                   97009.18
# 4       60       1939.23                  109980.00
# ...    ...           ...                        ...
# 19995   19       1349.60                  156766.97
# 19996   22       2019.78                   47924.80
# 19997   19       2252.03                   18629.88
# 19998   21       1845.35                   95430.73
# 19999   21       5233.16                  107966.03
#
#        Current Loan Expenses (USD) Expense Type 2  Credit Score  \
# 0                           396.72              N        799.14
# 1                           463.76              Y        833.31
# 2                           493.15              Y        627.44
# 3                           446.15              Y        833.20
# 4                           370.10              N           NaN
# ...                            ...            ...           ...
# 19995                       500.59              Y        684.32
# 19996                       243.02              Y        706.34
# 19997                       101.88              N        656.46
# 19998                       271.31              Y        865.46
# 19999                       983.45              Y        857.16
#
#       Has Active Credit Card Property Price  Income Stability_Low  \
# 0                Unpossessed       236644.5                  True
# 1                Unpossessed       142357.3                  True
# 2                Unpossessed      300991.24                  True
# 3                   Inactive       125612.1                 False
# 4                        NaN       180908.0                 False
# ...                      ...            ...                   ...
# 19995               Inactive       212778.0                  True
# 19996               Inactive       90816.95                  True
# 19997               Inactive       21566.27                  True
# 19998            Unpossessed      120281.17                  True
# 19999                 Active      133425.43                  True
#
#        Profession_Maternity leave  Profession_Pensioner  \
# 0                           False                 False
# 1                           False                 False
# 2                           False                 False
# 3                           False                  True
# 4                           False                  True
# ...                           ...                   ...
# 19995                       False                 False
# 19996                       False                 False
# 19997                       False                 False
# 19998                       False                 False
# 19999                       False                 False
#
#        Profession_State servant  Profession_Student  Profession_Unemployed  \
# 0                         False               False                  False
# 1                         False               False                  False
# 2                         False               False                  False
# 3                         False               False                  False
# 4                         False               False                  False
# ...                         ...                 ...                    ...
# 19995                     False               False                  False
# 19996                     False               False                  False
# 19997                     False               False                  False
# 19998                     False               False                  False
# 19999                     False               False                  False
#
#        Profession_Working  Location_Semi-Urban  Location_Urban  \
# 0                   False                 True           False
# 1                    True                False           False
# 2                    True                 True           False
# 3                   False                False           False
# 4                   False                False            True
# ...                   ...                  ...             ...
# 19995               False                 True           False
# 19996                True                False            True
# 19997                True                 True           False
# 19998                True                 True           False
# 19999                True                 True           False
#
#        Expense Type 1_Y  Co-Applicant_1  Co-Applicant_?
# 0                 False            True           False
# 1                  True            True           False
# 2                 False            True           False
# 3                 False           False           False
# 4                 False            True           False
# ...                 ...             ...             ...
# 19995              True            True           False
# 19996              True            True           False
# 19997              True           False           False
# 19998             False            True           False
# 19999              True           False           False
#
# [20000 rows x 20 columns]

# %% [markdown]
# ## Modeling

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression

# %% [markdown]
# K-FOLD CROSS VALIDATION

# %%
X = train_encoded.drop(columns=["Loan Sanction Amount (USD)"])
y = train_encoded["Loan Sanction Amount (USD)"]
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25)
print("Performing 5-Fold CV on Training Set")
lr = LinearRegression()
kf = KFold(n_splits=5, shuffle=True, random_state=42)

mse_scores = []
mae_scores = []
r2_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(X_train), 1):
    X_t, X_v = X_train.iloc[train_idx], X_train.iloc[val_idx]
    y_t, y_v = y_train.iloc[train_idx], y_train.iloc[val_idx]

    lr.fit(X_t, y_t)
    preds = lr.predict(X_v)

    mse = mean_squared_error(y_v, preds)
    mae = mean_absolute_error(y_v, preds)
    r2 = r2_score(y_v, preds)

    mse_scores.append(mse)
    mae_scores.append(mae)
    r2_scores.append(r2)

    print(f"Fold {fold} — MSE: {mse:.2f}, MAE: {mae:.2f}, R²: {r2:.2f}")

print("\n Average CV Performance:")
print(f"Avg MSE: {np.mean(mse_scores):.2f}")
print(f"Avg MAE: {np.mean(mae_scores):.2f}")
print(f"Avg R²: {np.mean(r2_scores):.2f}")
# Out:
# Performing 5-Fold CV on Training Set
# Fold 1 — MSE: 664326235.28, MAE: 17974.80, R²: 0.58
# Fold 2 — MSE: 613557085.41, MAE: 17679.92, R²: 0.63
# Fold 3 — MSE: 607312964.48, MAE: 17472.92, R²: 0.62
# Fold 4 — MSE: 640423201.48, MAE: 17909.03, R²: 0.61
# Fold 5 — MSE: 636117711.57, MAE: 17667.83, R²: 0.61
#
#  Average CV Performance:
# Avg MSE: 632347439.64
# Avg MAE: 17740.90
# Avg R²: 0.61

# %% [markdown]
# FINAL TRAINING ON FULL TRAIN SET

# %%
print("\n Training Final Model on Full Training Data")
lr.fit(X_train, y_train)
# Out:
#  Training Final Model on Full Training Data
# LinearRegression()

# %% [markdown]
# VALIDATION SET EVALUATION

# %%
val_preds = lr.predict(X_val)
print("\nValidation Set Evaluation:")
print(f"Validation MSE: {mean_squared_error(y_val, val_preds):.2f}")
print(f"Validation MAE: {mean_absolute_error(y_val, val_preds):.2f}")
print(f"Validation R²: {r2_score(y_val, val_preds):.2f}")
# Out:
# Validation Set Evaluation:
# Validation MSE: 644109929.95
# Validation MAE: 17675.84
# Validation R²: 0.61

# %% [markdown]
# Predicted Vs Actual Value

# %%
plt.figure(figsize=(7,5))
sorted_idx = y_val.sort_values().index
y_val_sorted = y_val.loc[sorted_idx].reset_index(drop=True)
val_preds_sorted = pd.Series(val_preds, index=y_val.index).loc[sorted_idx].reset_index(drop=True)

plt.xlabel("Actual Loan Sanction Amount")
plt.ylabel("Predicted Amount")
plt.title("Test Set: Actual vs Predicted")
sns.scatterplot(x=range(len(val_preds_sorted)), y=val_preds_sorted, label="Predicted", color="orange")
sns.scatterplot(x=range(len(y_val_sorted)), y=y_val_sorted, label="Actual", color="blue")
plt.tight_layout()
plt.show()

# %% [markdown]
# Bar Plot of Feature Coefficients

# %%
coefficients = lr.coef_
features = X_train.columns

# Create a DataFrame for sorting and better plotting
coef_df = pd.DataFrame({
    'Feature': features,
    'Coefficient': coefficients
}).sort_values(by='Coefficient', ascending=False)

# Plot
plt.figure(figsize=(10, 6))
bars = plt.barh(coef_df['Feature'], coef_df['Coefficient'], color=np.where(coef_df['Coefficient'] > 0, 'green', 'red'))

plt.xlabel("Coefficient Value")
plt.title("Linear Regression: Feature Coefficients")
plt.axvline(x=0, color='black', linewidth=0.8)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Residual Plot

# %%
residuals = y_val - val_preds

plt.figure(figsize=(8, 5))
sns.scatterplot(x=val_preds, y=residuals)
plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residual Plot")
plt.grid(True)
plt.tight_layout()
plt.show()
